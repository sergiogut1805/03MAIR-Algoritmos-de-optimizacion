767), (216, 209), (58, 352), (401, 766), (242, 569), (222, 866), (631, 916), (184, 370), (919, 375), (519, 367), (92, 122), (549, 122), (439, 127), (972, 334), (925, 888), (157, 137), (741, 151), (654, 120), (460, 144), (996, 444), (549, 86), (448, 767), (45, 752), (792, 62), (741, 300), (705, 695), (113, 457), (621, 884), (113, 143), (792, 574), (354, 147), (133, 219), (149, 652), (348, 440), (222, 84), (106, 248), (673, 722), (283, 453), (296, 858), (916, 174), (268, 419), (337, 620), (463, 51), (177, 191), (744, 914), (657, 565), (970, 142), (821, 474), (332, 723), (995, 30), (786, 134), (589, 943), (651, 328), (426, 910), (376, 994), (347, 147), (974, 472), (61, 84), (147, 182), (768, 609), (183, 332), (551, 36), (361, 203), (419, 737), (282, 27), (672, 51), (37, 542), (41, 999), (506, 745), (898, 663), (316, 446), (262, 639), (261, 241), (191, 676), (446, 277), (647, 18), (599, 900), (554, 982), (409, 975), (680, 843), (884, 437), (216, 353), (747, 131), (339, 921), (824, 141), (324, 882), (78, 398), (760, 526), (45, 203), (366, 118), (721, 986), (572, 410), (369, 911), (419, 712), (651, 452), (525, 9), (574, 87), (356, 705), (759, 70), (531, 927), (662, 250), (44, 815), (725, 286), (333, 2), (242, 743), (3, 222), (180, 736), (291, 362), (798, 945), (469, 112), (108, 888), (513, 284), (790, 356), (31, 301), (967, 838), (460, 231), (825, 147), (521, 743), (811, 464), (246, 791), (165, 189), (357, 90), (258, 122), (855, 54), (896, 653), (942, 940), (175, 653), (67, 74), (128, 805), (561, 685), (956, 779), (37, 486), (715, 748), (651, 114), (430, 108), (97, 444), (224, 315), (714, 737), (303, 23), (604, 47), (75, 344), (377, 161), (577, 99), (175, 630), (241, 33), (477, 95), (249, 951), (123, 604), (594, 342), (217, 163), (941, 648), (866, 64 ...

# %%
def distancia(A,B):
  if type(A) is int or type(A) is float:
    return  abs(B-A)
  else:
    return math.sqrt(sum([   (A[i]-B[i])**2 for i in range(len(A))   ]))
  
distancia((1,3), (2,5))
# Out:
# 2.23606797749979

# %%
#Fuerza Bruta
def distancia_fuerza_bruta(L):
  mejor_distancia = float("infinity") 
  
  A,B = (),()
  
  for i in range(len(L)):
    for j in range(i+1, len(L)):
      D = distancia(L[i],L[j])
      if D < mejor_distancia:
                A,B=L[i],L[j]
                mejor_distancia = D
  return [A,B] 

distancia_fuerza_bruta(LISTA_2D)
# Out:
# [(599, 938), (600, 938)]

# %%
def distancia_divide_y_venceras(L):
  #Si hay pocos por Fuerza Bruta
  if len(L) <10: 
    return  distancia_fuerza_bruta(L)
  
  
  #Dividir en listas grandes
  LISTA_IZQ = sorted(L, key=lambda x: x[0])[:len(L)//2]
  LISTA_DER = sorted(L, key=lambda x: x[0])[len(L)//2:]
  
  PUNTOS_LISTA_IZQ = distancia_divide_y_venceras(LISTA_IZQ)
  PUNTOS_LISTA_DER = distancia_divide_y_venceras(LISTA_DER)
  
  return distancia_fuerza_bruta(PUNTOS_LISTA_IZQ + PUNTOS_LISTA_DER)
  

@calcular_tiempo  
def LANZA(L):
  return distancia_divide_y_venceras(L)
  
SOL = LANZA(LISTA_2D[:1000])

print(SOL)
# Out:
#  Tiempo de ejecución para algoritmo: 0.0155768394470214843750000
# [(599, 938), (600, 938)]

# %%
TARIFAS = [
[0,5,4,3,999,999,999],
[999,0,999,2,3,999,11],
[999,999, 0,1,999,4,10],
[999,999,999, 0,5,6,9],
[999,999, 999,999,0,999,4],
[999,999, 999,999,999,0,3],
[999,999,999,999,999,999,0]
]

#Paseo por el rio
def Precios(TARIFAS):
  N = len(TARIFAS[0])
  
  PRECIOS = [ [9999]*N for i in [9999]*N ]
  RUTAS    = [ [""]*N for i in [9999]*N ]
  
  for i in range(N-1):
    for j in range(i+1,N):
      MIN = TARIFAS[i][j]
      RUTAS[i][j] = i
      
      for k in range(i,j):
        if PRECIOS[i][k]+ TARIFAS[k][j] < MIN:
          MIN = min( MIN , PRECIOS[i][k]+ TARIFAS[k][j] )
          RUTAS[i][j] = k
      PRECIOS[i][j] = MIN
      
  return PRECIOS, RUTAS

  
PRECIOS, RUTAS = Precios(TARIFAS)

print(PRECIOS)

print()

print(RUTAS)

def calcular_ruta(RUTAS, desde, hasta):
  if desde == hasta:
    #print("Ir a :" + str(desde))
    return desde 
  else:
    return str(calcular_ruta(RUTAS, desde, RUTAS[desde][hasta])) +  ',' + str(RUTAS[desde][hasta]) 

print("\nLa ruta es:")  
calcular_ruta(RUTAS, 0,6)
# Out:
# [[9999, 5, 4, 3, 8, 8, 11], [9999, 9999, 999, 2, 3, 8, 7], [9999, 9999, 9999, 1, 6, 4, 7], [9999, 9999, 9999, 9999, 5, 6, 9], [9999, 9999, 9999, 9999, 9999, 999, 4], [9999, 9999, 9999, 9999, 9999, 9999, 3], [9999, 9999, 9999, 9999, 9999, 9999, 9999]]
#
# [['', 0, 0, 0, 1, 2, 5], ['', '', 1, 1, 1, 3, 4], ['', '', '', 2, 3, 2, 5], ['', '', '', '', 3, 3, 3], ['', '', '', '', '', 4, 4], ['', '', '', '', '', '', 5], ['', '', '', '', '', '', '']]
#
# La ruta es:
# '0,0,2,5'

# %%
#Calculo de Tiempos(Isabel Vazques). (Pte. analizar aportación de Miguel Angel Soto)
from time import time
def calcular_tiempo(f):
   
    def wrapper(*args, **kwargs):        
        inicio = time()       
        resultado = f(*args, **kwargs)       
        tiempo = float(time() - inicio)     
        print("\r\n Tiempo de ejecución para algoritmo: "+"{0:.25f}".format(tiempo))
        return resultado
    
    return wrapper
